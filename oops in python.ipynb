# %%
class Computer:
    def __init__(self):
        self.name="Kavin"
        self.age="18"


c1=Computer()
c2=Computer()

print(c1.name)
print(c2.age)
# Out:
# Kavin
# 18

# %%
class Computer:
    def __init__(self):
        self.name="Kavin"
        self.age=18

c1=Computer()
c2=Computer()

def update(self):
        self.name="raji"
        
update(c1)        

print(c1.name)
print(c2.age)
# Out:
# raji
# 18

# %%
class Computer:
    def __init__(self):
        self.name= "Kavin"
        self.age=20

def update(self):
    self.age=19

c1=Computer()
c2=Computer()

c1.name= "rani"
c1.age=21

update(c1)

print(c1.name)
print(c2.name)
# Out:
# rani
# Kavin
